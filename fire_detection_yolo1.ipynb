# %%
#check if NVIDIA GPU IS ENABLED
# !nvidia-smi
# Out:
# Sat Jun 26 04:19:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
#  **Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  2018-10-28-13-49-04-496.jpg
#  20200303_115552.jpg
#  acivity_diagram2.jpg
#  acivity_diagram.jpg
#  app-debug.apk
#  bigdata2018.pdf
#  bigdata.JPG
# 'C lab questions .docx'
#  Classroom
# 'cnn_f (1).JPG'
#  cnn_f.JPG
# 'cnn_hand (1).JPG'
#  cnn_hand.JPG
# 'cnn_m (1).JPG'
#  cnn_m.JPG
# 'Colab Notebooks'
#  conv_block.jpg
#  credit_card.docx
#  cross_validation_iris.JPG
#  cross_validation_wine1.JPG
#  cross_validation_wine2.JPG
# 'CV18-19 - B&W.docx'
# 'Data_Communication_and_Networking (1).pdf'
#  Data_Communication_and_Networking.pdf
#  DBSCAN_wine.JPG
#  DBSCAN_wine.py
#  decision_bio1.JPG
#  decision_bio2.JPG
#  decision_wine.JPG
#  deep1.JPG
# 'deep_breast_cancer (1).JPG'
#  deep_breast_cancer1.JPG
#  deep_breast_cancer.JPG
#  deep_dropOut.JPG
# 'dnn_f (1).JPG'
#  dnn_f.JPG
# 'dnn_m (1).JPG'
#  dnn_m.JPG
# 'final 2 4-12-19-1.pdf'
# 'final 2 4-12-19.pdf'
#  fire_detection_yolo1.ipynb
#  fruits_naive.JPG
#  fruits_naive_predit.JPG
#  fruits_svm.JPG
# ...

# %% [markdown]
# **1) Clone, configure & compile Darknet**

# %%
#clone
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15138, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 15138 (delta 29), reused 50 (delta 23), pack-reused 15073
# Receiving objects: 100% (15138/15138), 13.47 MiB | 20.65 MiB/s, done.
# Resolving deltas: 100% (10274/10274), done.

# %%
#configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
#compile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# **2) Configure yolov3.cfg file**

# %%
#make s copy of yolov3.cfg
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
#change lines in yolov3_training.cfg file
# !sed -i '3 s@batch=1@# batch=1@' cfg/yolov3_training.cfg
# !sed -i ' 4 s@subdivisions=1@# subdivisions=1@' cfg/yolov3_training.cfg
# !sed -i '6 s@# batch=64@batch=64@' cfg/yolov3_training.cfg
# !sed -i '7 s@# subdivisions=16@subdivisions=16@' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 2000/' cfg/yolov3_training.cfg
# !sed -i '22 s@steps=400000,450000@steps=1600,1800@' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %% [markdown]
# **3) Create .names and .data files**

# %%
# !echo -e 'fire' > data/obj.names
# !echo -e 'classes= 4\ntrain = data/train.txt\nvalid = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data

# %% [markdown]
# **4) Save yolov3_training.cfg and obj.names files in google drive**

# %%
# !cp cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_testing.cfg
# !cp data/obj.names /mydrive/yolov3/classes.txt

# %% [markdown]
# **5) Create a folder and unzip image dataset**

# %%
# !mkdir data/obj
# !unzip /mydrive/yolov3/images.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3/images.zip
#   inflating: data/obj/images/10.png
#   inflating: data/obj/images/10.txt
#   inflating: data/obj/images/108.jpg
#   inflating: data/obj/images/108.txt
#   inflating: data/obj/images/110.jpg
#   inflating: data/obj/images/110.txt
#   inflating: data/obj/images/112.jpg
#   inflating: data/obj/images/112.txt
#   inflating: data/obj/images/114.jpg
#   inflating: data/obj/images/114.txt
#   inflating: data/obj/images/119.png
#   inflating: data/obj/images/119.txt
#   inflating: data/obj/images/12.png
#   inflating: data/obj/images/12.txt
#   inflating: data/obj/images/13.jpg
#   inflating: data/obj/images/13.txt
#   inflating: data/obj/images/136.jpg
#   inflating: data/obj/images/136.txt
#   inflating: data/obj/images/138.jpg
#   inflating: data/obj/images/138.txt
#   inflating: data/obj/images/14.jpg
#   inflating: data/obj/images/14.txt
#   inflating: data/obj/images/143.jpg
#   inflating: data/obj/images/143.txt
# ...

# %% [markdown]
# **6) Create train.txt and test.txt files**

# %%
import glob
image_list = glob.glob("data/obj/images/*.jpg")
image_list.extend(glob.glob("data/obj/images/*.JPG"))
image_list.extend(glob.glob("data/obj/images/*.png"))
image_test = image_list[:int(len(image_list) * 0.15)]
image_train = image_list[int(len(image_list) * 0.15):]
print("Total Number of images : ",len(image_list))
print("Number of train images : ",len(image_train))
print("Number of test images : ",len(image_test))
with open("data/train.txt","w") as f:
    f.write("\n".join(image_train))
with open("data/test.txt","w") as f:
    f.write("\n".join(image_test))
# Out:
# Total Number of images :  669
# Number of train images :  569
# Number of test images :  100

# %% [markdown]
# **7) Dowloadpre-trained weights for the Convolutional layers file**

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-06-26 04:24:01--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M   101MB/s    in 1.5s
#
# 2021-06-26 04:24:03 (101 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **8) Start Training**

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
#uncomment below and comment above to re-start your training fromlast saved weights
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 194569, rewritten_bbox = 0.000000 %
#
#  1926: 0.454885, 0.382602 avg loss, 0.000010 rate, 9.861463 seconds, 123264 images, 0.288429 hours left
# Loaded: 0.000058 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.808806), count: 4, class_loss = 0.842607, iou_loss = 0.199761, total_loss = 1.042368
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.593623), count: 2, class_loss = 0.516397, iou_loss = 0.412722, total_loss = 0.929119
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000044, iou_loss = 0.000000, total_loss = 0.000044
#  total_bbox = 194575, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.813699), count: 4, class_loss = 0.435698, iou_loss = 0.329834, total_loss = 0.765533
# ...

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
imShow('chart.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-096d9cb64b19> in <module>()
# ----> 1 imShow('chart.png')
#
# <ipython-input-1-d45ca047db47> in imShow(path)
#       5
#       6   image = cv2.imread(path)
# ----> 7   height, width = image.shape[:2]
#       8   resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)
#       9
#
# AttributeError: 'NoneType' object has no attribute 'shape'
